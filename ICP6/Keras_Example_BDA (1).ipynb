# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path_to_csv = '/content/gdrive/My Drive/diabetes.csv'

# %%
import keras
import pandas
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense, Activation
from keras.initializers import glorot_normal
from sklearn.preprocessing import StandardScaler


# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv(path_to_csv, header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.15, random_state=87)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
np.random.seed(155)
my_first_nn = Sequential()
my_first_nn.add(Dense(50, input_dim=8, activation='relu', kernel_initializer=glorot_normal()))
my_first_nn.add(Dense(50, activation='relu'))
my_first_nn.add(Dense(1, activation='sigmoid'))

optimizer = Adam(learning_rate=0.0005)
my_first_nn.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['acc'])
my_first_nn.fit(X_train, Y_train, epochs=350,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/350
# 21/21 [==============================] - 1s 2ms/step - loss: 0.6496 - acc: 0.6856
# Epoch 2/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5926 - acc: 0.7270
# Epoch 3/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5528 - acc: 0.7500
# Epoch 4/350
# 21/21 [==============================] - 0s 4ms/step - loss: 0.5219 - acc: 0.7607
# Epoch 5/350
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4967 - acc: 0.7699
# Epoch 6/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4789 - acc: 0.7791
# Epoch 7/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4677 - acc: 0.7853
# Epoch 8/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4572 - acc: 0.7853
# Epoch 9/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4508 - acc: 0.7868
# Epoch 10/350
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4453 - acc: 0.7899
# Epoch 11/350
# ...
